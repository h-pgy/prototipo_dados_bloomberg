# %%
import requests
from time import sleep
from config import TIME_BETWEEN_REQUESTS, TOKEN_OLHO_VIVO

# %%
print('Tempo entre requisições:', TIME_BETWEEN_REQUESTS, 'segundos')
# Out:
# Tempo entre requisições: 30 segundos
